# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (2.27.1)

# %%
import requests

# %%
url = 'https://api.exchangerate-api.com/v6/latest'

req = requests.get(url)

print(req.status_code)
# Out:
# 200

# %%
dados = req.json()

# %%
print(dados)
# Out:
# {'result': 'success', 'provider': 'https://www.exchangerate-api.com', 'documentation': 'https://www.exchangerate-api.com/docs/free', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1657497752, 'time_last_update_utc': 'Mon, 11 Jul 2022 00:02:32 +0000', 'time_next_update_unix': 1657585422, 'time_next_update_utc': 'Tue, 12 Jul 2022 00:23:42 +0000', 'time_eol_unix': 0, 'base_code': 'USD', 'rates': {'USD': 1, 'AED': 3.67, 'AFN': 87.53, 'ALL': 114.07, 'AMD': 409.31, 'ANG': 1.79, 'AOA': 429.56, 'ARS': 126.03, 'AUD': 1.46, 'AWG': 1.79, 'AZN': 1.69, 'BAM': 1.92, 'BBD': 2, 'BDT': 92.84, 'BGN': 1.92, 'BHD': 0.376, 'BIF': 2027.69, 'BMD': 1, 'BND': 1.4, 'BOB': 6.85, 'BRL': 5.34, 'BSD': 1, 'BTN': 79.34, 'BWP': 12.57, 'BYN': 3.17, 'BZD': 2, 'CAD': 1.29, 'CDF': 1994.53, 'CHF': 0.977, 'CLP': 950.72, 'CNY': 6.7, 'COP': 4364.39, 'CRC': 685.24, 'CUP': 24, 'CVE': 108.43, 'CZK': 24.23, 'DJF': 177.72, 'DKK': 7.34, 'DOP': 54.57, 'DZD': 146.5, 'EGP': 18.81, 'ERN': 15, 'ETB': 51.89, 'EUR': 0.983, 'FJD': 2.2, 'FKP': 0.832, 'FOK': 7.34, 'GBP': 0.833, 'GEL': 2.88, 'GGP': 0.832, 'GHS': 8.22, 'GIP': 0.832, 'GMD': 53.98, 'GNF': 8639.13, 'GTQ': 7.72, 'GYD': 208.14, 'HKD': 7.85, 'HNL': 24.44, 'HRK': 7.41, 'HTG': 116.46, 'HUF': 398.16, 'IDR': 14993.31, 'ILS': 3.47, 'IMP': 0.832, 'INR': 79.34, 'IQD': 1451.55, 'IRR': 41938.06, 'ISK': 137.39, 'JEP': 0.832, 'JMD': 150.09, 'JOD': 0.709, 'JPY': 136.27, 'KES': 117.77, 'KGS': 79.84, 'KHR': 4052.18, 'KID': 1.46, 'KMF': 483.78, 'KRW': 1296.66, 'KWD': 0.3, 'KYD': 0.833, 'KZT': 470.91, 'LAK': 16906.97, 'LBP': 1507.5, 'LKR': 359.18, 'LRD': 151.56, 'LSL': 16.83, 'LYD': 4.81, 'MAD': 9.97, 'MDL': 19.15, 'MGA': 4084.18, 'MKD': 60.48, 'MMK': 1841.08, 'MNT': 3125.66, 'MOP': 8.09, 'MRU': 36.31, 'MUR': 45.33, 'MVR': 15.38, 'MWK': 1030.55, 'MXN': 20.49, 'MYR': 4.42, 'MZN': 64.47, 'NAD': 16.83, 'NGN': 413.76, 'NIO': 35.71, 'NOK': 10.1, 'NPR': 126.95, 'NZD': 1.62, 'OMR': 0.384, 'PAB': 1, 'PEN': 3.88, 'PGK': 3.51, 'PHP': 55.93, 'PKR': 206.59, 'PLN': 4.69, 'PYG': 6837.09, 'QAR': 3.64, 'RON': 4.84, 'RSD': 115.35, 'RUB': 62.48, 'RWF': 1050.95, 'SAR': 3.75, 'SBD': 8.01, 'SCR': 13.26, 'SDG': 470.34, 'SEK': 10.52, 'SGD': 1.4, 'SHP': 0.832, 'SLL': 13157.3, 'SOS': 574.38, 'SRD': 22.21, 'SSP': 504.02, 'STN': 24.09, 'SYP': 2495.76, 'SZL': 16.83, 'THB': 36, 'TJS': 10.74, 'TMT': 3.49, 'TND': 3.04, 'TOP': 2.33, 'TRY': 17.27, 'TTD': 6.76, 'TVD': 1.46, 'TWD': 29.72, 'TZS': 2325.67, 'UAH': 30.14, 'UGX': 3748.78, 'UYU': 40, 'UZS': 10850.63, 'VES': 5.57, 'VND': 23335.43, 'VUV': 118.36, 'WST': 2.63, 'XAF': 645.03, 'XCD': 2.7, 'XDR': 0.761, 'XOF': 645.03, 'XPF': 117.34, 'YER': 249.15, 'ZAR': 16.83, 'ZMW': 16.38, 'ZWL': 374.49}}

# %%
valor_reais = float(input('Informe o valor em R$ a ser convertido\n'))
cotacao = dados['rates']['BRL']
print(f'R${valor_reais} em dólar US$ {(valor_reais / cotacao):.2f}')
# Out:
# Informe o valor em R$ a ser convertido
# 100
# R$100.0 em dólar US$ 18.73
